# %% [markdown]
# ## Problem 1
# (Declaring variables, conditionals, loops)
#
# Complete the code below to have the find out the number of times the person scored above a 80%.

# %%
grades = [65, 55, 86, 92, 100, 45, 88, 65]

# %% [markdown]
# ## Problem 2
# (Variable Types)
#
# 1. If I want to store the name of a person, what type should I use?
# 2. If I want to store someone's age (without decimals) what type should I use?
# 3. What type would I use to store an approximation for pi?
# 4. How are lists and dictionaries different? How are they similar?

# %% [markdown]
# ## Problem 3
# (Declaring var, loops)
#
# Write a loop to calculate the first 15 fibonacci numbers.
#
# Reminder that the fibonacci sequence is generated by adding together the previous two numbers (starting with 0 and 1).
#
# 0, 1, 1, 2, 3, 5, 8, 13, 21, ...

# %% [markdown]
# ## Additional Problems
#
# [Check out CodingBat](https://codingbat.com/python/Warmup-1)
