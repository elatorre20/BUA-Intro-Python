# %% [markdown]
# ## Section 8: Bringing it all together
#
# Over the past 7 classes, you have learned the fundamental skills of programming in the Python language. All programming, no matter how complex the final product, can be broken down into the types of statements, operators, and control flow that you have learned how to use. The most important part of programming, however, is not learning syntax or memorizing the quirks of a particular language. The most important skill is abstract thinking. Taking an idea for a progam and breaking it down into simpler parts, and then those parts into yet simpler ones, is what will allow you to write programs to do almost anything. More than anything, practicing this skill is what will allow you to improve as a programmer and create cool and interesting things. With that in mind, we come to our final exercise. Take a moment to think about something interesting and moderately complex that can be drawn on a 2-dimensional canvas. You are not limited to regular polygons; think of all of the things that can be done with highly irregular shapes, overlapping elements, colors, and so on. In the text cell below, jot down a description of your idea. Once you have that, break it down into components that will be simpler to draw. Once you have an outline, you can then begin writing your code in the code cell.

# %%
from turtle import Turtle
yertle = Turtle()
# start your drawing here
yertle.clearscreen()
yertle.goto(0,0)
